# %% [markdown]
# # Data‑Scaling Study for CAD Text OCR with PaddleOCR
#
# This starter notebook walks you through:
# 1. Preparing a labelled **crop‑level** dataset from CAD drawings
# 2. Fine‑tuning the PaddleOCR recognition model on incrementally larger subsets
# 3. Plotting a learning curve to find the data‑saturation point
#
# > **Tip** Run each section sequentially after filling in paths relevant to your environment.

# %%
# --- 1. Environment setup ---------------------------------------------------
# Uncomment the next line if PaddleOCR isn't installed in your kernel
# !pip install --upgrade paddlepaddle paddleocr matplotlib pandas scikit-learn tqdm

import os, json, random, shutil, time, pathlib, pickle
from pathlib import Path
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from tqdm import tqdm

# PaddleOCR imports (lazy – comment out if you want to test without training)
from paddleocr import PaddleOCR

# %%
os.path.getsize(path)¶

# %%
"PP-OCRv4_server_rec"

"PP-OCRv5_server_rec"

# %%
# --- 2. Project paths --------------------------------------------------------
DATA_ROOT = Path('data/cad_crops')          # folder with images
ANNOT_CSV = Path('data/labels.csv')         # CSV: image_path,transcription
MODEL_DIR = Path('models/')                 # where fine‑tuned checkpoints go
RESULTS_CSV = Path('results_scaling.csv')   # learning‑curve log

# Make sure directories exist
MODEL_DIR.mkdir(parents=True, exist_ok=True)

# %%
os.listdir("data/cad_crops")
# Out:
# ['d17da87d-7c46-435a-b37e-85719ffdcc84_crop_0.gt.txt',
#  '3_00845_crop_0.gt.txt',
#  '4_04257_crop_0.gt.txt',
#  '4_06143_crop_0.gt.txt',
#  '4_01673_crop_1.gt.txt',
#  '2_00493_crop_0.gt.txt',
#  '1_02138_crop_1.gt.txt',
#  '4_01393_crop_0.jpg',
#  '1_02138_crop_0.jpg',
#  '0_12000_crop_0.jpg',
#  '4_06556_crop_0.jpg',
#  '3_01064_crop_0.jpg',
#  '0_07231_crop_0.gt.txt',
#  '3b1413f4-8fb5-4dd9-b2a7-813305fcf319_crop_10.gt.txt',
#  '72ca758c-51c2-4d16-9303-bcd05a6969e8_crop_2.gt.txt',
#  '9bb674ff-bfa1-4137-9887-4c53885679a1_crop_0.gt.txt',
#  '6_00415_crop_0.jpg',
#  '0_03967_crop_0.gt.txt',
#  '4_03549_crop_0.jpg',
#  '4_02755_crop_0.jpg',
#  'c52fb089-f312-4688-b9a0-9017d357557a_crop_0.jpg',
#  '4a0e6c10-77c7-4ca4-a92b-569e7edcc325_crop_0.jpg',
#  '2_02063_crop_0.jpg',
#  '7f085b86-db90-4aa4-838e-057c65e6e1d2_crop_3.gt.txt',
#  '11dc141d-b526-48e6-bdcc-7078ef257e78_crop_0.jpg',
#  '29d552ae-018d-4cec-ad19-f0ad0d80abdb_crop_0.jpg',
#  '0_08392_crop_0.gt.txt',
#  '4_00851_crop_0.gt.txt',
#  '4f9971ea-377c-44fa-9c32-52c44d235b47_crop_0.gt.txt',
#  '2_02909_crop_0.gt.txt',
#  '4_06049_crop_0.jpg',
#  '5_00051_crop_0.jpg',
#  '3_01437_crop_2.gt.txt',
#  '1_01444_crop_0.gt.txt',
#  '2_03002_crop_0.jpg',
#  '0_06587_crop_0.jpg',
#  'f08fa2f6-d15c-4828-b6dc-72bfe8f37228_crop_0.jpg',
#  '0_16475_crop_0.jpg',
#  '0_07390_crop_0.jpg',
#  '2_02615_crop_0.jpg',
#  '2_03409_crop_0.jpg',
#  '406cf63c-21b4-4f86-a163-d670ae713769_crop_0.jpg',
#  '0_06950_crop_0.gt.txt',
#  '6d27d3d6-812c-4f6a-a053-199789af7de0_crop_0.gt.txt',
#  '9946bdc4-7f3c-41f8-88d0-5047ae5871a9_crop_0.jpg',
#  '0_16335_crop_0.gt.txt',
#  '4_04358_crop_1.jpg',
#  '8e89b845-e567-4243-8025-6b2434a18a78_crop_0.gt.txt',
#  '1_03552_crop_0.jpg',
#  '0_06800_crop_0.gt.txt',
#  '0_02773_crop_0.gt.txt',
#  '3_00880_crop_0.jpg',
#  'f03cf8e9-c8e6-4b62-ba67-58d23b52276e_crop_0.jpg',
#  'cdc75612-9b13-4ba6-bfae-368124362802_crop_0.gt.txt',
#  '24217e12-1ba1-4345-8d94-a01fe918003f_crop_0.jpg',
#  '3_01612_crop_0.jpg',
#  '1_04397_crop_0.jpg',
#  '2_01409_crop_0.gt.txt',
#  '4_06025_crop_1.gt.txt',
#  '46b543d6-93e0-42d3-880d-4e89975b9d5a_crop_0.gt.txt',
#  '4_01715_crop_0.gt.txt',
#  '37f15ad3-abbd-475c-8470-f5f689f620f5_crop_0.jpg',
#  '2_01559_crop_0.gt.txt',
#  '4_06175_crop_1.gt.txt',
#  '3_01274_crop_0.gt.txt',
#  'badd4601-bb89-4aa9-9a7b-32c8c1c89ecb_crop_0.gt.txt',
#  'f521f888-f741-4755-bedb-4887863ff90c_crop_0.gt.txt',
#  '1_01697_crop_0.jpg',
#  '1_02814_crop_0.gt.txt',
#  '3_00673_crop_0.jpg',
#  '4_05095_crop_2.jpg',
#  '6_00501_crop_0.jpg',
#  '3_01095_crop_0.gt.txt',
#  '4_04298_crop_0.jpg',
#  '2_02177_crop_0.jpg',
#  '45f43766-b39c-426f-a898-8bba1be026cd_crop_1.gt.txt',
#  '741576cd-f463-4a76-ae9a-a25fe10966fc_crop_2.gt.txt',
#  '4_05626_crop_1.jpg',
#  'a4435ea1-7982-42ad-9bed-b19842007499_crop_0.jpg',
#  '1_03230_crop_0.jpg',
#  '4_01287_crop_0.jpg',
#  '39220293-c4ac-4366-8f69-e4568e4dc9a7_crop_0.gt.txt',
#  '0_19099_crop_0.jpg',
#  '2_01936_crop_0.gt.txt',
#  '2_03089_crop_0.gt.txt',
#  '4_02992_crop_1.gt.txt',
#  '4_04796_crop_2.jpg',
#  '2_01866_crop_0.gt.txt',
#  'ca1dcab6-c973-49fc-98c3-5b96bfe72a60_crop_0.gt.txt',
#  '3_01170_crop_0.jpg',
#  '4_01081_crop_0.gt.txt',
#  '4_05409_crop_0.gt.txt',
#  '4_04787_crop_0.jpg',
#  '2_02468_crop_0.jpg',
#  '12f5ae6d-1d6c-47f8-8f7c-2742d13acf4b_crop_0.jpg',
#  '5afd1665-6175-4a26-9dc2-8ecb8f421677_crop_1.gt.txt',
#  '0_06216_crop_0.gt.txt',
#  '4_04883_crop_1.jpg',
#  '4_05921_crop_0.gt.txt',
#  '2_02036_crop_0.jpg',
#  '4_02700_crop_0.jpg',
#  '56d84e2b-19b5-49f4-a1fa-6a607761b3fb_crop_0.gt.txt',
#  'd45df823-251c-4621-aaa7-8192b8749bd8_crop_1.gt.txt',
#  '4_00778_crop_1.jpg',
#  '3_01333_crop_0.gt.txt',
#  '3_01998_crop_0.gt.txt',
#  '3_01263_crop_0.gt.txt',
#  '4_02833_crop_1.jpg',
#  '8c5cd21c-2726-4d3f-88d5-931166b82a40_crop_5.gt.txt',
#  '0_19849_crop_0.jpg',
#  '0_13756_crop_0.jpg',
#  '5_00004_crop_0.jpg',
#  '0_16989_crop_0.gt.txt',
#  '1_02119_crop_0.gt.txt',
#  '1_04685_crop_0.gt.txt',
#  '1_02472_crop_0.jpg',
#  '0_21030_crop_0.jpg',
#  '2_03057_crop_0.jpg',
#  'eff1860b-b718-464b-bd32-3e9741c7e5a2_crop_0.gt.txt',
#  '0_19515_crop_0.gt.txt',
#  'dff76075-944e-431f-95a3-18324d23bc31_crop_0.jpg',
#  '1_00944_crop_0.jpg',
#  '0cd935d5-3478-42d2-b147-7e8067166e33_crop_2.gt.txt',
#  '2_02417_crop_1.gt.txt',
#  'b48761bd-ccf8-4f8a-86df-c8ca3cb606c3_crop_0.gt.txt',
#  '1_02803_crop_0.gt.txt',
#  'c11b190f-a07b-4177-99c9-de8b5b880166_crop_2.gt.txt',
#  '0_04349_crop_0.gt.txt',
#  '1_03413_crop_0.jpg',
#  '2_01392_crop_0.jpg',
#  '4_05005_crop_1.jpg',
#  '1_04111_crop_0.gt.txt',
#  '2_03548_crop_0.jpg',
#  '0_17728_crop_0.jpg',
#  '1_04041_crop_0.gt.txt',
#  '4_02062_crop_0.jpg',
#  '18d5b11e-4d68-45aa-bc76-364b8ea4a0f7_crop_0.jpg',
#  'f0ef20c9-5034-4d79-93a8-be6f015d170f_crop_1.jpg',
#  'affa5856-2a6d-43d9-9046-0454774f0689_crop_0.gt.txt',
#  '4_07573_crop_2.jpg',
#  '6_00322_crop_0.jpg',
#  '0_10981_crop_0.gt.txt',
#  '0_19060_crop_0.gt.txt',
#  '4_03879_crop_0.gt.txt',
#  '2_01921_crop_0.gt.txt',
#  '2_00491_crop_0.jpg',
#  '86eb3b0e-f6a4-4b87-ad1c-fa3bdf5e2363_crop_1.gt.txt',
#  '1_02310_crop_0.jpg',
#  '2_00276_crop_1.gt.txt',
#  '4_03929_crop_0.gt.txt',
#  '4_06420_crop_0.jpg',
#  '1_04497_crop_0.jpg',
#  '978e1898-294e-40e3-9f73-72aacb68980a_crop_1.jpg',
#  '3_01112_crop_0.jpg',
#  '26ed649f-083e-4b90-9ff4-01c380fce5ed_crop_3.jpg',
#  '10b2c763-d0c6-4097-9702-02db72e36a9b_crop_0.jpg',
#  '1_04819_crop_0.jpg',
#  '3_00661_crop_0.gt.txt',
#  '4_02081_crop_1.jpg',
#  '1_00036_crop_1.jpg',
#  '2_02258_crop_0.gt.txt',
#  '43709ad0-19dd-480f-bfe6-4486c90cf9f0_crop_1.jpg',
#  'ce54495f-2966-4ace-98a2-74b2d4c83a37_crop_0.gt.txt',
#  'ceedd77a-0cfe-4008-946a-c6fa6e1b835a_crop_0.jpg',
#  '2_02308_crop_0.gt.txt',
#  '1_03252_crop_0.jpg',
#  '4_02014_crop_0.gt.txt',
#  'a5b11a26-9913-4d71-bc4c-89da5d0541c2_crop_1.jpg',
#  '2_03616_crop_0.jpg',
#  '0_17476_crop_0.jpg',
#  '0_17670_crop_0.gt.txt',
#  '3f132d2b-db7a-4f0f-aa99-3b839f652943_crop_2.gt.txt',
#  '4_07323_crop_0.jpg',
#  '23fcd8c0-9ec6-4836-928d-1d78d8da50ac_crop_1.jpg',
#  '1_01881_crop_0.gt.txt',
#  '70eaf567-d232-431c-ac0e-05630677a2d7_crop_0.gt.txt',
#  '92cce15e-06e7-4904-adf1-adcea40581af_crop_0.jpg',
#  '4_00968_crop_0.jpg',
#  '50d5e454-0c25-4944-b675-3e1762f78e2a_crop_0.jpg',
#  '2_02115_crop_0.jpg',
#  '0_07490_crop_0.jpg',
#  '3b1413f4-8fb5-4dd9-b2a7-813305fcf319_crop_3.gt.txt',
#  '3_02000_crop_0.gt.txt',
#  '1_00694_crop_0.jpg',
#  '3_00244_crop_0.gt.txt',
#  '3_02150_crop_0.gt.txt',
#  '1_01488_crop_0.jpg',
#  '3_00314_crop_0.gt.txt',
#  '5_00008_crop_0.gt.txt',
#  'aee3b2f4-95fc-43d2-bec1-34757aa6f928_crop_2.jpg',
#  '4_07145_crop_1.gt.txt',
#  '2_00569_crop_0.gt.txt',
#  '170cf0d0-e27a-4ae0-9fdd-53cf1b8f9680_crop_0.gt.txt',
#  '98d3c369-5275-40ab-9866-f632ec21e2be_crop_0.jpg',
#  '6_00563_crop_0.jpg',
#  '2_00439_crop_0.gt.txt',
#  '0_01049_crop_0.jpg',
#  'cd03e734-c7f0-4186-aa95-aa7d760f0dc9_crop_0.jpg',
#  '35afc796-d6fd-471e-9951-7dae6d5a9eb3_crop_3.gt.txt',
#  '0d15cc63-fca9-4056-9996-c23a1ccab7f4_crop_0.jpg',
#  '3_01670_crop_0.jpg',
#  '0_05895_crop_0.gt.txt',
#  '1_03824_crop_0.gt.txt',
#  '1_03974_crop_0.gt.txt',
#  '1dca8b54-031b-4429-8569-d61858a58c7c_crop_0.jpg',
#  '4_01909_crop_0.jpg',
#  '1_03530_crop_0.jpg',
#  '1_00137_crop_1.gt.txt',
#  '4_01438_crop_1.gt.txt',
#  'a42f46ba-86da-462c-9744-7cc1377a05c4_crop_0.gt.txt',
#  '4_06308_crop_0.gt.txt',
#  '4_02780_crop_0.gt.txt',
#  '59bfbbc6-d6e7-48cc-8421-da8813d603d4_crop_0.jpg',
#  '4_00494_crop_0.gt.txt',
#  '2_01674_crop_1.gt.txt',
#  '2_00788_crop_0.gt.txt',
#  '2_03174_crop_0.jpg',
#  '4_01596_crop_2.jpg',
#  '63c12115-60b7-4419-b672-a6233aa1ac24_crop_3.gt.txt',
#  '0_21113_crop_0.jpg',
#  'c8f39712-135a-4ca0-aa7c-a5d08ba3dd37_crop_0.jpg',
#  '4_04087_crop_0.jpg',
#  '72506afc-1ba5-40cb-9930-2ab59d1e2a42_crop_0.jpg',
#  'a8139584-4c1d-4b8a-b1f1-995ee7305322_crop_0.jpg',
#  '0_08563_crop_0.jpg',
#  '4_07781_crop_1.gt.txt',
#  '2_00906_crop_0.gt.txt',
#  'd0fd77dd-85d8-40ee-b8e3-7dd07e294a12_crop_0.jpg',
#  '4_04589_crop_2.jpg',
#  '27029d68-891a-4085-ac2c-0ddb028e2090_crop_2.jpg',
#  '0_18117_crop_0.gt.txt',
#  '0_08089_crop_0.gt.txt',
#  '754e8486-73c1-41f2-8533-4b216b65c452_crop_1.jpg',
#  '2_02677_crop_0.jpg',
#  '0_13149_crop_0.gt.txt',
#  '0b2eb8b5-7969-4c9d-9652-4a9d8cf05b5e_crop_0.jpg',
#  '4_07450_crop_2.jpg',
#  '1_00512_crop_1.gt.txt',
#  '6_00201_crop_0.jpg',
#  '1_05136_crop_0.gt.txt',
#  '4_07476_crop_0.jpg',
#  '4_01785_crop_2.gt.txt',
#  '3_01358_crop_0.jpg',
#  '60f62c11-6779-41ae-b3a9-4e482fd8c329_crop_1.jpg',
#  '2_02640_crop_0.jpg',
#  '6fcd0fff-286a-44dc-93a4-1562c2a38190_crop_0.jpg',
#  '1_04560_crop_1.jpg',
#  '3_00902_crop_0.gt.txt',
#  '3_00852_crop_0.gt.txt',
#  'a15dfe7a-647f-4204-b82d-ff90e28e3bf0_crop_2.gt.txt',
#  '0_22693_crop_0.gt.txt',
#  '2_02790_crop_0.gt.txt',
#  '4_06004_crop_0.gt.txt',
#  '6_00236_crop_0.jpg',
#  '4_04240_crop_0.gt.txt',
#  '4_00798_crop_0.gt.txt',
#  '4_06154_crop_0.gt.txt',
#  'da883f80-7c91-4801-b4f5-8382bda59ed1_crop_1.gt.txt',
#  '4_07169_crop_0.jpg',
#  '4_06375_crop_0.jpg',
#  '3_01647_crop_0.jpg',
#  '3_01720_crop_1.gt.txt',
#  '4_03005_crop_1.gt.txt',
#  '1_03507_crop_0.jpg',
#  '4_04665_crop_0.gt.txt',
#  '4_03664_crop_2.jpg',
#  '2_01286_crop_0.jpg',
#  '1_00850_crop_0.jpg',
#  '4_02469_crop_0.jpg',
#  '4_03675_crop_0.jpg',
#  '2_03143_crop_0.jpg',
#  '33ea1cd5-0790-4ecb-b658-58cc352e155d_crop_0.jpg',
#  '0_07753_crop_0.gt.txt',
#  '4_06364_crop_2.jpg',
#  '0_13642_crop_0.jpg',
#  '5_00110_crop_0.jpg',
#  '2_02154_crop_0.gt.txt',
#  '2_02004_crop_0.gt.txt',
#  '4_02927_crop_1.jpg',
#  'd2d5cf20-5889-4204-9d10-b63377198200_crop_0.gt.txt',
#  '0_22280_crop_0.jpg',
#  '59216696-136e-480e-9b86-ea0d10aa00d1_crop_0.gt.txt',
#  '1_02566_crop_0.jpg',
#  '1_01831_crop_0.jpg',
#  '4_03886_crop_0.jpg',
#  '0_15738_crop_0.gt.txt',
#  '0_00262_crop_0.jpg',
#  '4_01011_crop_2.gt.txt',
#  '1_03617_crop_0.gt.txt',
#  '6_00554_crop_0.jpg',
#  '1_01503_crop_0.gt.txt',
#  '1_03747_crop_0.gt.txt',
#  '3_00339_crop_0.jpg',
#  '4a5e48b6-70cb-47d5-9d6d-cc837968dd4e_crop_0.gt.txt',
#  '0_17009_crop_0.gt.txt',
#  '6576a3b8-0659-4d1a-9db7-d45e800b399b_crop_2.jpg',
#  '3_01125_crop_0.jpg',
#  'ccf19bab-e71c-4542-a8b2-1b23b4211308_crop_0.jpg',
#  '1_04452_crop_1.gt.txt',
#  '1_03899_crop_0.gt.txt',
#  '21a015a1-fd7f-41d7-b618-9bede19f8aec_crop_0.gt.txt',
#  'b64a8414-9bd0-456d-944e-ef2262ca8302_crop_0.gt.txt',
#  '4_01485_crop_1.gt.txt',
#  '2_02421_crop_0.gt.txt',
#  '2_02571_crop_0.gt.txt',
#  '3_00148_crop_0.gt.txt',
#  '59036aeb-a17c-4421-acb6-18dd12a99498_crop_2.gt.txt',
#  '3_00018_crop_0.gt.txt',
#  '0_01561_crop_0.jpg',
#  '4_06406_crop_2.jpg',
#  '4_05935_crop_2.gt.txt',
#  '4_04550_crop_0.jpg',
#  'dba5f270-a8d1-43aa-bd48-16c54b92a226_crop_0.gt.txt',
#  '1_02146_crop_1.jpg',
#  '4_07816_crop_2.jpg',
#  'cacc83cd-676f-4136-b9f4-828fbc87db36_crop_3.gt.txt',
#  '0_06126_crop_0.jpg',
#  '4956de71-d22e-4be0-bca0-011aa3617b0b_crop_0.gt.txt',
#  '3_00991_crop_0.gt.txt',
#  '2_01766_crop_0.jpg',
#  '1032c202-4c8e-4444-a08d-8b6e44ea194b_crop_1.gt.txt',
#  '5_00026_crop_0.gt.txt',
#  '0_08663_crop_0.gt.txt',
#  'cf7c9efb-be95-4fd1-8634-64cb61736425_crop_0.jpg',
#  'c6a7fdf4-1efa-4d34-b759-6b4988e73d97_crop_0.jpg',
#  '4_03028_crop_1.jpg',
#  '4_04383_crop_0.gt.txt',
#  'e80fe8db-db40-4050-b646-499074d9f102_crop_0.gt.txt',
#  '0_10519_crop_0.jpg',
#  '0_08316_crop_0.gt.txt',
#  '4_05253_crop_0.jpg',
#  '4_01929_crop_1.gt.txt',
#  '2_00032_crop_0.gt.txt',
#  '2_02276_crop_0.gt.txt',
#  '4_02818_crop_0.jpg',
#  '2_00162_crop_0.gt.txt',
#  '1_00421_crop_0.jpg',
#  '890630e4-2245-480f-82e6-4ff1161f1a9d_crop_0.jpg',
#  '1_03976_crop_0.jpg',
#  '1_01771_crop_0.gt.txt',
#  '0_15019_crop_0.jpg',
#  '2_00065_crop_0.jpg',
#  '4_02809_crop_2.jpg',
#  '0_02325_crop_0.jpg',
#  '98cd871b-32d9-4c35-a7a6-aa7aea3ef88a_crop_0.gt.txt',
#  '4_07196_crop_0.jpg',
#  '1_05121_crop_0.jpg',
#  '2_00878_crop_0.gt.txt',
#  '4_03327_crop_1.gt.txt',
#  '2_00383_crop_0.gt.txt',
#  '2_02097_crop_0.gt.txt',
#  '4_01033_crop_1.gt.txt',
#  '4_03879_crop_0.jpg',
#  '9bc1bcd2-c8d3-41a9-bcfc-e7f1255f5c80_crop_1.gt.txt',
#  '1_01440_crop_0.jpg',
#  'c0580495-5eca-4ff2-80a8-fbf35a95040b_crop_1.gt.txt',
#  '4_07056_crop_1.jpg',
#  'd5ba61db-0bab-4f9d-b295-26dd7f2028b7_crop_0.gt.txt',
#  '820167d7-4ada-417e-a2cc-fe6549e0da9c_crop_0.gt.txt',
#  '0_07458_crop_0.jpg',
#  'd4667b1c-3f05-4240-b8f4-17a7a4d58311_crop_0.gt.txt',
#  '4_01732_crop_0.jpg',
#  '0_11273_crop_0.gt.txt',
#  'd5e63b2d-5878-4709-93fb-ca5a83cb179c_crop_0.gt.txt',
#  '21acabba-929b-46e0-ab57-3ba6d2371b98_crop_0.jpg',
#  'ca5e0e89-daa0-4f82-8ad6-98bf171f7608_crop_0.jpg',
#  '1_04140_crop_0.jpg',
#  '1_03684_crop_0.gt.txt',
#  'dcc63947-f3ac-4f8a-91b4-ae7579a79485_crop_1.jpg',
#  '1_05118_crop_0.gt.txt',
#  '25cfd437-d281-47d7-8e2d-e4165943d33f_crop_0.gt.txt',
#  '0_07054_crop_0.gt.txt',
#  'a15dfe7a-647f-4204-b82d-ff90e28e3bf0_crop_2.jpg',
#  '4_05531_crop_0.jpg',
#  '3_02003_crop_0.jpg',
#  'e43f7e31-27c0-4108-8195-84347b3d787b_crop_0.jpg',
#  '4_06397_crop_3.gt.txt',
#  '4_06326_crop_0.gt.txt',
#  '2_01995_crop_0.jpg',
#  '6_00309_crop_1.jpg',
#  'e6b57600-3c54-41f2-8be0-8b1acff9c368_crop_0.gt.txt',
#  '2_00707_crop_0.jpg',
#  '36d206ad-975b-4d2d-a9c6-41532280ca21_crop_0.gt.txt',
#  '1_02086_crop_0.jpg',
#  '4_06276_crop_0.gt.txt',
#  'c824124d-7097-49f6-9f3f-56f102634d01_crop_0.gt.txt',
#  '3_02034_crop_0.jpg',
#  '6_00083_crop_0.jpg',
#  'ab3afaee-bf46-4d40-b10a-a681bfa89431_crop_0.gt.txt',
#  '0_17489_crop_0.jpg',
#  '0_16695_crop_0.jpg',
#  '4a219cc4-41e1-4361-9885-9016c298cd04_crop_0.gt.txt',
#  '4_00938_crop_0.gt.txt',
#  '2_02860_crop_0.gt.txt',
#  '4_04829_crop_1.jpg',
#  '0_14550_crop_0.jpg',
#  '63c12115-60b7-4419-b672-a6233aa1ac24_crop_2.jpg',
#  '1_04468_crop_0.jpg',
#  '0_12189_crop_0.jpg',
#  'af23daae-5b05-47b7-bc3c-ea392bfb68a0_crop_0.gt.txt',
#  '1_01942_crop_0.gt.txt',
#  '46bc0782-06b4-4c4f-95b8-f7104bcb45fd_crop_0.gt.txt',
#  '18984c43-190e-434c-858d-0cb32ca0545d_crop_0.jpg',
#  '1_01477_crop_0.jpg',
#  '4_07061_crop_1.jpg',
#  'fa262edf-9d65-4bd5-b8fb-8875618e7552_crop_0.gt.txt',
#  'b7e8685c-c9a0-4104-adbb-3e9b3a3746ed_crop_1.jpg',
#  '3de01240-0d4b-48a2-b9c9-5ee8388ce435_crop_0.gt.txt',
#  '3_02093_crop_0.gt.txt',
#  '4_00997_crop_0.jpg',
#  '3_00387_crop_0.gt.txt',
#  '0_18707_crop_0.jpg',
#  '9b771eff-02a6-4bc2-961f-59ee72b68bfd_crop_0.gt.txt',
#  '4_04078_crop_0.jpg',
#  '0_05956_crop_0.gt.txt',
#  '0_03461_crop_0.gt.txt',
#  'f1ca6ff3-d15d-4c68-bc35-766ef8e60d07_crop_0.gt.txt',
#  '36acb30b-340e-4683-b38c-c966e59c1336_crop_1.jpg',
#  'ff1cedcd-49b8-4b88-a7f2-1d7a7ce97329_crop_0.gt.txt',
#  '1_01108_crop_0.gt.txt',
#  '2_02397_crop_0.jpg',
#  '4_05092_crop_2.gt.txt',
#  '1_01058_crop_0.gt.txt',
#  '1_03941_crop_0.jpg',
#  '1f835ee2-ebf5-465d-a110-e94de044db5e_crop_0.jpg',
#  '2_00052_crop_0.jpg',
#  '9d2c7bb6-447d-4abb-a7df-96e3ce8d10db_crop_0.jpg',
#  '4fcb9a4a-4003-43a9-9f6b-665bd5dfd3bc_crop_0.gt.txt',
#  '88209dea-2ca9-43d8-9472-dd937cdbd440_crop_0.gt.txt',
#  '0_08083_crop_0.jpg',
#  '4174b601-2f80-4c18-98b7-1c96772a6cdb_crop_2.jpg',
#  '3_00493_crop_0.jpg',
#  '3_02272_crop_0.gt.txt',
#  '4_00172_crop_0.gt.txt',
#  '2_01392_crop_1.gt.txt',
#  '3_02249_crop_0.jpg',
#  '4_05406_crop_1.gt.txt',
#  '2_00995_crop_0.gt.txt',
#  '3_00413_crop_0.gt.txt',
#  'e0cf73ff-def3-4f3f-ac66-6fe152bba37d_crop_0.gt.txt',
#  '2_02688_crop_0.jpg',
#  '3_00543_crop_0.gt.txt',
#  '4_01375_crop_4.jpg',
#  '61b5924f-fb9d-4f48-9ccf-c6bcebd90d55_crop_1.gt.txt',
#  '191cac59-e882-4557-afaa-8d3e6df4a075_crop_0.jpg',
#  'aa1b53ad-c4c9-475a-a299-6ee0d147077c_crop_0.jpg',
#  '3_01390_crop_0.jpg',
#  '4_02203_crop_1.jpg',
#  '2_00613_crop_0.jpg',
#  '0_10008_crop_0.gt.txt',
#  '61b5924f-fb9d-4f48-9ccf-c6bcebd90d55_crop_2.jpg',
#  '4_03341_crop_1.jpg',
#  '4_06972_crop_0.jpg',
#  'fee65369-8f42-4374-9cc5-98262ed313ac_crop_0.gt.txt',
#  '4_00318_crop_1.gt.txt',
#  '4_01084_crop_1.jpg',
#  '3_02117_crop_0.jpg',
#  '82c5c5fa-f7e6-4ac8-b4a7-b36b3c4c9850_crop_0.jpg',
#  '1_00257_crop_0.jpg',
#  '0_13251_crop_2.gt.txt',
#  '3_01785_crop_0.gt.txt',
#  'f64f2181-bd17-4304-bd6e-7df86d704d05_crop_0.gt.txt',
#  '4_01791_crop_0.gt.txt',
#  '1_02803_crop_0.jpg',
#  '4_02429_crop_1.gt.txt',
#  '4_02579_crop_1.gt.txt',
#  '4_01626_crop_0.jpg',
#  '35cedd30-5985-4e41-b4d6-397c7e866bd8_crop_0.jpg',
#  '4_05249_crop_0.gt.txt',
#  '2_01110_crop_0.jpg',
#  '4_03485_crop_0.gt.txt',
#  '0_19438_crop_0.jpg',
#  'cdc75612-9b13-4ba6-bfae-368124362802_crop_0.jpg',
#  '6_00831_crop_0.jpg',
#  'dfaf1991-64b9-4822-a586-95945115987a_crop_0.gt.txt',
#  '0_01195_crop_0.jpg',
#  'b4e59103-48c8-41fd-9578-8a74ddb978ce_crop_0.jpg',
#  '1_04746_crop_0.gt.txt',
#  '1_00835_crop_0.gt.txt',
#  '1_01899_crop_1.gt.txt',
#  '1_04616_crop_0.gt.txt',
#  'e7ea4aa9-eef9-4c83-b1ab-567b56745c54_crop_3.gt.txt',
#  '0_09548_crop_0.gt.txt',
#  '2_00171_crop_0.jpg',
#  '3_01011_crop_0.gt.txt',
#  '64dcd568-5a7d-4121-b28f-4f8bd4c3d67f_crop_0.gt.txt',
#  '3_01141_crop_0.gt.txt',
#  '4_03664_crop_0.gt.txt',
#  'ad979e42-1a08-4792-9c6e-68537e420fea_crop_0.jpg',
#  '4_06310_crop_1.gt.txt',
#  '4_04154_crop_1.gt.txt',
#  '4_07082_crop_0.jpg',
#  '2_03578_crop_0.gt.txt',
#  '4aeb50f4-9dd2-403e-9be5-a394afa602cd_crop_2.jpg',
#  '1_05035_crop_0.jpg',
#  '4_02798_crop_1.gt.txt',
#  '2_03428_crop_0.gt.txt',
#  '4_03734_crop_0.gt.txt',
#  '0_18459_crop_0.jpg',
#  '40d76036-de09-463b-8a25-d109149c94c4_crop_2.gt.txt',
#  '4c173253-2830-4c2e-8b5b-0676a5cd1a91_crop_0.jpg',
#  'ff574199-94a5-47ac-bea6-1e2bc05646d4_crop_0.gt.txt',
#  '1_02890_crop_0.gt.txt',
#  '0_14244_crop_0.gt.txt',
#  '4_00358_crop_0.jpg',
#  '2aa8e83f-2d6b-4337-9246-1c4e112f7d15_crop_0.jpg',
#  '1_04182_crop_0.gt.txt',
#  '0_15412_crop_0.jpg',
#  '2_01672_crop_0.jpg',
#  '24a7ce63-48f8-449d-9b85-b75bd113aa50_crop_0.jpg',
#  '14157d26-34cb-4f4b-8350-c2e2b202339a_crop_0.jpg',
#  '0_10842_crop_0.gt.txt',
#  'dfcd231c-1a88-4ff2-87d5-38f4f25b1d30_crop_0.jpg',
#  '3_01564_crop_0.gt.txt',
#  '2_01941_crop_1.jpg',
#  '3_01434_crop_0.gt.txt',
#  '4_04444_crop_0.jpg',
#  '4_02916_crop_1.gt.txt',
#  '2_01249_crop_0.gt.txt',
#  '4_06665_crop_1.gt.txt',
#  '4_01155_crop_0.gt.txt',
#  '4_03241_crop_0.gt.txt',
#  '4_03281_crop_0.jpg',
#  'e4da046b-ff56-4bf3-a191-f337a56b2034_crop_0.gt.txt',
#  '2_01319_crop_0.gt.txt',
#  '4_03568_crop_0.gt.txt',
#  '2_01430_crop_0.gt.txt',
#  '5f2085d7-996e-4bc2-8328-1db182b2fd61_crop_0.jpg',
#  '589c0652-d212-47ba-ae39-d3b5fb91f7ca_crop_0.gt.txt',
#  '94082b6d-d2b4-4606-b819-a06c86082611_crop_3.gt.txt',
#  '2_01645_crop_0.jpg',
#  '3_00098_crop_0.jpg',
#  '2bd04df3-1771-41cc-90a4-c3bfdb1c22c0_crop_0.gt.txt',
#  '1_04701_crop_0.jpg',
#  '3_01284_crop_0.jpg',
#  '0_09694_crop_0.jpg',
#  '6_00742_crop_0.gt.txt',
#  'dbe66fa9-2b5c-406c-b93f-c8dd2b330e80_crop_0.gt.txt',
#  '1_02137_crop_0.gt.txt',
#  '669f504b-81d3-49f4-9cf1-4acf8fc35dd0_crop_2.gt.txt',
#  '2_00146_crop_0.jpg',
#  '1_03855_crop_0.jpg',
#  '0_19672_crop_0.jpg',
#  '1_02512_crop_0.gt.txt',
#  '2_01145_crop_0.gt.txt',
#  '4_07495_crop_0.gt.txt',
#  '4_05370_crop_0.jpg',
#  '4_01309_crop_0.gt.txt',
#  '2_03251_crop_0.gt.txt',
#  '2_02283_crop_0.jpg',
#  '1_00502_crop_0.jpg',
#  '3_01668_crop_0.gt.txt',
#  '5c1e77fd-2e6b-4e48-9393-9a39bc90e85a_crop_1.jpg',
#  '0_04612_crop_0.gt.txt',
#  '6_00186_crop_0.gt.txt',
#  '3_01968_crop_0.jpg',
#  '0_04742_crop_0.gt.txt',
#  '4_01922_crop_1.jpg',
#  '6_00806_crop_0.jpg',
#  '6_00488_crop_0.jpg',
#  '3_01489_crop_0.gt.txt',
#  '4_02250_crop_1.gt.txt',
#  '0_20099_crop_0.jpg',
#  '1_01563_crop_0.jpg',
#  '4_03907_crop_0.gt.txt',
#  '0_17082_crop_0.jpg',
#  '0_14444_crop_0.jpg',
#  '2_00624_crop_0.jpg',
#  '2_01438_crop_0.jpg',
#  '2_01781_crop_0.gt.txt',
#  '4_00561_crop_1.gt.txt',
#  '2_03495_crop_0.gt.txt',
#  'cd57d8c3-3b4c-44fb-9809-bad6773e7a25_crop_2.jpg',
#  '217ad716-34f7-4258-88f7-7fd73bc44646_crop_3.gt.txt',
#  '62990f08-ebaf-48ee-832f-80f1c0902be8_crop_0.gt.txt',
#  'ca02e3cd-5aec-4205-bb93-dcf8afdc63da_crop_1.gt.txt',
#  '3_02120_crop_0.jpg',
#  '6_00197_crop_0.jpg',
#  '0_01833_crop_0.jpg',
#  '4_02794_crop_2.gt.txt',
#  'b59366cf-9b6b-4136-bbef-b93220ef3a42_crop_1.jpg',
#  '0_20908_crop_0.jpg',
#  '0_14902_crop_0.gt.txt',
#  '4_06676_crop_1.jpg',
#  '1_00260_crop_0.jpg',
#  '0_06123_crop_0.gt.txt',
#  '0_00449_crop_0.gt.txt',
#  '1_00321_crop_0.jpg',
#  '4_00042_crop_2.jpg',
#  '6_00605_crop_0.gt.txt',
#  'e6f93118-490a-469d-9860-6ddbbd235e20_crop_1.gt.txt',
#  '3_02061_crop_0.jpg',
#  '4_05848_crop_0.gt.txt',
#  '68ee3ac2-d00e-48f9-a67a-8c13e43d0f08_crop_0.jpg',
#  '4_06804_crop_0.jpg',
#  '2_03663_crop_0.gt.txt',
#  '2_01577_crop_0.gt.txt',
#  'f82ed19e-48b3-495f-9967-751cbcf88b19_crop_1.jpg',
#  '4_05542_crop_2.jpg',
#  '2_01579_crop_0.jpg',
#  'f209085f-386e-42a3-82d3-32bbbe71427c_crop_2.gt.txt',
#  '0_15719_crop_0.jpg',
#  'af6ed3fa-3e7c-4031-b0e9-d656e2ef5b43_crop_0.gt.txt',
#  '4_00053_crop_0.jpg',
#  '2_01152_crop_0.gt.txt',
#  '4_01741_crop_2.jpg',
#  '1_01422_crop_0.jpg',
#  '2_01002_crop_0.gt.txt',
#  '2_03246_crop_0.gt.txt',
#  '0_09276_crop_0.gt.txt',
#  '0_11994_crop_0.jpg',
#  '55f3fed4-c165-4879-bae6-cfcb5f437c63_crop_0.gt.txt',
#  '43709ad0-19dd-480f-bfe6-4486c90cf9f0_crop_0.gt.txt',
#  '0_02883_crop_0.gt.txt',
#  '6_00220_crop_0.gt.txt',
#  '3_01829_crop_0.jpg',
#  '4_06195_crop_0.jpg',
#  '4_07389_crop_0.jpg',
#  'e68ace88-d4a8-4981-a0d8-6005b16e91ea_crop_0.jpg',
#  '2_01066_crop_0.jpg',
#  '4_07025_crop_3.jpg',
#  '1_04962_crop_0.gt.txt',
#  '4_01750_crop_0.jpg',
#  '1_02505_crop_0.gt.txt',
#  '1_00741_crop_0.gt.txt',
#  'a93455db-68a3-4b41-9643-a93d550b572c_crop_0.gt.txt',
#  '3338a0f4-4471-4bc6-83d7-ca79c8de8997_crop_0.jpg',
#  '39859cd9-156a-406a-a030-dc273cb44805_crop_0.gt.txt',
#  '74595278-1aa1-48c7-a5f8-f42d700c95a6_crop_1.gt.txt',
#  '4_05577_crop_0.gt.txt',
#  '4_03840_crop_0.gt.txt',
#  '4_07663_crop_0.gt.txt',
#  '6a68e504-9c75-4b6f-a79d-5d2a0103dc90_crop_0.gt.txt',
#  '5529737b-3455-469f-9840-a34787e74ff5_crop_0.gt.txt',
#  '4_01690_crop_1.jpg',
#  'e1452d7e-316d-4f7d-8366-d099767143dc_crop_0.gt.txt',
#  '8bdd6bad-0d5b-4551-a484-d29c69a4a93e_crop_1.gt.txt',
#  '3_00848_crop_0.jpg',
#  '45374671-e077-47f6-8121-5f6da3596aa2_crop_0.gt.txt',
#  '6_00191_crop_0.gt.txt',
#  '1_03914_crop_0.jpg',
#  '1_02786_crop_0.jpg',
#  '4_04390_crop_1.jpg',
#  '2_00007_crop_0.jpg',
#  'e9f32b2f-05ec-4df1-a217-6f01d7d73c8c_crop_3.jpg',
#  '02c4134a-993c-4b78-9300-e8a46c938636_crop_1.jpg',
#  '0_10064_crop_0.jpg',
#  '0e658df2-b195-4d71-a609-93e7d1124f1c_crop_2.jpg',
#  '835e56c7-6e71-463d-9499-6e74d8b0fcc3_crop_8.gt.txt',
#  '0_00913_crop_0.jpg',
#  '0_11278_crop_0.jpg',
#  '0_14845_crop_0.gt.txt',
#  '1_04640_crop_0.jpg',
#  '4_07865_crop_0.jpg',
#  '7005f89b-116f-43f5-b487-f7de7b663f96_crop_1.jpg',
#  'b1688170-c41a-426b-b48f-28e353f037b9_crop_0.gt.txt',
#  '2_01796_crop_0.gt.txt',
#  '2_03482_crop_0.gt.txt',
#  '4_06911_crop_1.gt.txt',
#  '87c970a4-25a0-4266-8c1d-74139c93b244_crop_0.jpg',
#  '2_00518_crop_0.jpg',
#  '2_00996_crop_0.jpg',
#  '5f7870be-ee21-484a-9acd-66b84b4f3d12_crop_2.jpg',
#  '2_00013_crop_1.gt.txt',
#  '97893aa0-7975-4ecc-8aba-65abf9402699_crop_2.gt.txt',
#  'b0a97430-e911-4af3-b9ec-056b2919a7f4_crop_0.gt.txt',
#  '2ee0c9e4-dea4-444c-96e0-878ab9716ad0_crop_0.gt.txt',
#  '3_01792_crop_0.gt.txt',
#  '0_00181_crop_0.gt.txt',
#  'a7630fd4-ea4a-47cb-ad30-1c90829d64f2_crop_0.gt.txt',
#  '6_00836_crop_0.gt.txt',
#  '4_07852_crop_0.jpg',
#  '1276dfaa-af7c-455a-9391-7e6eacb89d11_crop_3.jpg',
#  '1_04374_crop_0.gt.txt',
#  'cb05ba69-13d7-4cb6-964a-7cd7903cf93b_crop_2.gt.txt',
#  '6_00783_crop_0.jpg',
#  '28a91b2a-8d5f-4436-ae47-03b3993be03c_crop_0.gt.txt',
#  'bc31c61c-5927-4da4-b0c4-56b070132d2e_crop_0.gt.txt',
#  '27029d68-891a-4085-ac2c-0ddb028e2090_crop_0.gt.txt',
#  'f9341b40-e509-4078-969d-9d8c99cf8c7b_crop_0.jpg',
#  '1_04368_crop_0.jpg',
#  '4_04859_crop_1.gt.txt',
#  '4_03562_crop_1.jpg',
#  '0_02370_crop_0.jpg',
#  '0_19770_crop_0.gt.txt',
#  '1_03923_crop_0.jpg',
#  '2_00030_crop_0.jpg',
#  '2_03394_crop_0.jpg',
#  '5f7870be-ee21-484a-9acd-66b84b4f3d12_crop_2.gt.txt',
#  '2_02188_crop_0.jpg',
#  '1_00138_crop_0.gt.txt',
#  '0_16017_crop_0.gt.txt',
#  'df43d2a3-8820-4c4c-baf3-24dbd8c62345_crop_0.gt.txt',
#  '4_04267_crop_0.jpg',
#  '0_02451_crop_0.gt.txt',
#  '0_00615_crop_0.gt.txt',
#  '496180e4-833d-4628-97c4-1cc01ae01ada_crop_0.gt.txt',
#  '0_16147_crop_0.gt.txt',
#  '6_00509_crop_0.gt.txt',
#  '0_14303_crop_0.gt.txt',
#  ...]

# %%
print(len([name for name in os.listdir("data/cad_crops")]))


file_count = len([name for name in os.listdir("data/cad_crops")])


batches = file_count / 367


print(f"Batches: {batches}")
# Out:
# 36777
# Batches: 100.20980926430518

# %%
# --- 3. Load annotations -----------------------------------------------------
df = pd.read_csv(ANNOT_CSV)
print(f'Total labelled crops: {len(df):,}')
df.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 2
#       1 # --- 3. Load annotations -----------------------------------------------------
# ----> 2 df = pd.read_csv(ANNOT_CSV)
#       3 print(f'Total labelled crops: {len(df):,}')
#       4 df.head()
#
# File ~/cerpro/ocr-rec-lab/ocr-rec-lab-venv/lib/python3.10/site-packages/pandas/io/parsers/readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)
#    1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File ~/cerpro/ocr-rec-lab/ocr-rec-lab-venv/lib/python3.10/site-packages/pandas/io/parsers/readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File ~/cerpro/ocr-rec-lab/ocr-rec-lab-venv/lib/python3.10/site-packages/pandas/io/parsers/readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File ~/cerpro/ocr-rec-lab/ocr-rec-lab-venv/lib/python3.10/site-packages/pandas/io/parsers/readers.py:1880, in TextFileReader._make_engine(self, f, engine)
#    1878     if "b" not in mode:
#    1879         mode += "b"
# -> 1880 self.handles = get_handle(
#    1881     f,
#    1882     mode,
#    1883     encoding=self.options.get("encoding", None),
#    1884     compression=self.options.get("compression", None),
#    1885     memory_map=self.options.get("memory_map", False),
#    1886     is_text=is_text,
#    1887     errors=self.options.get("encoding_errors", "strict"),
#    1888     storage_options=self.options.get("storage_options", None),
#    1889 )
#    1890 assert self.handles is not None
#    1891 f = self.handles.handle
#
# File ~/cerpro/ocr-rec-lab/ocr-rec-lab-venv/lib/python3.10/site-packages/pandas/io/common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'data/labels.csv'

# %%
# --- 4. Train/Val/Test split -------------------------------------------------
from sklearn.model_selection import train_test_split

train_df, temp_df = train_test_split(df, test_size=0.2, random_state=42, shuffle=True)
val_df, test_df   = train_test_split(temp_df, test_size=0.5, random_state=42, shuffle=True)

print(f'Train: {len(train_df):,}  |  Val: {len(val_df):,}  |  Test: {len(test_df):,}')

# %%
# Utility: save a subset CSV for PaddleOCR training ---------------------------
def save_subset(df_subset, name):
    subset_path = ANNOT_CSV.parent / f'{name}.csv'
    df_subset.to_csv(subset_path, index=False)
    return subset_path

# %%
# --- 5. Fine‑tuning function -------------------------------------------------
def finetune_paddleocr(train_csv, val_csv, out_dir, epochs=20, lr=1e-4):
    """Minimal wrapper around PaddleOCR CLI training.
    Replace this with your preferred training loop or the official tools.
    """
    # NOTE: This is a placeholder. Insert your own training invocation here.
    # You could call `paddleocr/tools/train.py -c configs/rec/PP-OCRv4/...` programmatically
    # and parse logs to extract best‑val accuracy.
    
    # Simulate training time & accuracy for demo purposes
    import random, time
    time.sleep(2)  # pretend we trained
    val_acc = random.uniform(0.7, 0.93)  # dummy accuracy
    return val_acc

# %%
# --- 6. Data‑scaling experiment --------------------------------------------
subset_sizes = [100, 300, 600, 1000, 2000, 4000, 8000]
results = []

for n in subset_sizes:
    print(f'\n=== Training on {n:,} samples ===')
    # Sample n rows from train_df (or use all if n exceeds size)
    subset_df = train_df.sample(n=min(n, len(train_df)), random_state=42)
    subset_csv = save_subset(subset_df, f'train_{n}')
    val_csv    = save_subset(val_df, 'val')  # use full val set

    acc = finetune_paddleocr(subset_csv, val_csv, MODEL_DIR / f'model_{n}')
    print(f'Val accuracy: {acc*100:.2f}%')
    results.append({'subset': n, 'val_acc': acc})

# Save results
pd.DataFrame(results).to_csv(RESULTS_CSV, index=False)
results

# %%
# --- 7. Plot learning curve --------------------------------------------------
df_res = pd.read_csv(RESULTS_CSV)

plt.figure(figsize=(6,4))
plt.plot(df_res['subset'], df_res['val_acc']*100, marker='o')
plt.title('Learning curve: CAD OCR fine‑tuning')
plt.xlabel('Number of annotated image crops')
plt.ylabel('Validation accuracy (%)')
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 8 Results interpretation & next steps
#
# * **Look for the elbow:** where accuracy gain per data‑doubling drops below ~0.5 pp.
# * If the curve is still rising steeply at 8 k samples, plan to label more or use synthetic augmentation.
# * Otherwise, focus on data quality: balanced glyph coverage, realistic noise/blur augmentations, etc.
#
# Good luck, and happy fine‑tuning!
